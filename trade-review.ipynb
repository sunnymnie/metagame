# %% [markdown]
# # Testing

# %%
import binance_helpers as bh
import matplotlib.pyplot as plt
import pandas as pd
import model as m
import importlib
importlib.reload(m)
# Out:
# <module 'model' from '/Users/SunnyNie/Documents/Investing/metagame/model.py'>

# %%
trades = pd.read_csv("data/trades.csv", index_col=0, parse_dates=True)

# %%
t = trades.trades.iloc[-10000:]

# %%
# Out:
# timestamp
# 2019-10-20 18:00:00     beam
# 2019-10-20 20:00:00      nkn
# 2019-10-20 22:00:00      mft
# 2019-10-21 00:00:00     dock
# 2019-10-21 02:00:00      chz
#                        ...
# 2022-01-30 16:00:00      gto
# 2022-01-30 18:00:00      fio
# 2022-01-30 20:00:00     ctxc
# 2022-01-30 22:00:00    cocos
# 2022-01-31 00:00:00      key
# Name: trades, Length: 10000, dtype: object

# %%
a = pd.DataFrame({"a":[3,4,5,6], "price":[2,2,2,2]}).set_index("a")
b = pd.DataFrame({"a":[4,5,6], "price":[1,1,1]}).set_index("a")

# %%
a = a.price.rename("a")
b = b.price.rename("b")

# %%
pd.concat([a, b], axis=1)
# Out:
#    a    b
# a
# 3  2  NaN
# 4  2  1.0
# 5  2  1.0
# 6  2  1.0

# %%
list(m.read_profile().keys())
# Out:
# ['1INCH',
#  'AAVE',
#  'ADA',
#  'AERGO',
#  'AGLD',
#  'AION',
#  'AKRO',
#  'ALCX',
#  'ALGO',
#  'ALICE',
#  'ALPHA',
#  'AMP',
#  'ANKR',
#  'ANT',
#  'AR',
#  'ARDR',
#  'ARPA',
#  'ATOM',
#  'AUCTION',
#  'AUDIO',
#  'AUTO',
#  'AVA',
#  'AVAX',
#  'AXS',
#  'BADGER',
#  'BAKE',
#  'BAL',
#  'BAND',
#  'BAT',
#  'BCH',
#  'BEL',
#  'BICO',
#  'BLZ',
#  'BNB',
#  'BNT',
#  'BOND',
#  'BTG',
#  'BTS',
#  'CELO',
#  'CELR',
#  'CFX',
#  'CHR',
#  'CHZ',
#  'CKB',
#  'CLV',
#  'COMP',
#  'COTI',
#  'CRV',
#  'CTK',
#  'CTSI',
#  'CTXC',
#  'CVC',
#  'CVX',
#  'DASH',
#  'DATA',
#  'DCR',
#  'DGB',
#  'DIA',
#  'DNT',
#  'DOCK',
#  'DODO',
#  'DOGE',
#  'DOT',
#  'DUSK',
#  'DYDX',
#  'EGLD',
#  'ELF',
#  'ENJ',
#  'ENS',
#  'EOS',
#  'ETC',
#  'ETH',
#  'FARM',
#  'FET',
#  'FIL',
#  'FIO',
#  'FIRO',
#  'FIS',
#  'FLM',
#  'FLOW',
#  'FRONT',
#  'FTM',
#  'FTT',
#  'FUN',
#  'GALA',
#  'GAS',
#  'GNO',
#  'GRT',
#  'GTC',
#  'GTO',
#  'HBAR',
#  'HIVE',
#  'ICP',
#  'ICX',
# ...

# %%
m.update_profile()
# Out:
#  |██████████████████████████████████████████████████| 100.0%

# %%
m.save_profile({})

# %%
import requests

# %%
fail = requests.get("https://data.messari.io/api/v2/assets/asdfasdf/profile")

# %%
fail.json()['status']
# Out:
# {'elapsed': 4,
#  'timestamp': '2022-01-21T01:43:46.801111693Z',
#  'error_code': 404,
#  'error_message': 'Not Found'}

# %%
fail.status_code
# Out:
# 404

# %%
response = requests.get("https://data.messari.io/api/v2/assets/1inch/profile")

# %%
response.json()['data']
# Out:
# {'id': '55a7b511-5d79-4a8f-ab38-487f8225b415',
#  'serial_id': 5931,
#  'symbol': '1INCH',
#  'name': '1inch',
#  'slug': '1inch',
#  'contract_addresses': [{'platform': 'avalanche',
#    'contract_address': '0xd501281565bf7789224523144fe5d98e8b28f267'},
#   {'platform': 'polygon-pos',
#    'contract_address': '0x9c2c5fd7b07e95ee044ddeba0e97a665f142394f'},
#   {'platform': 'harmony-shard-0',
#    'contract_address': '0x58f1b044d8308812881a1433d9bbeff99975e70c'},
#   {'platform': 'binance-smart-chain',
#    'contract_address': '0x111111111117dc0aa78b770fa6a738034120c302'},
#   {'platform': 'ethereum',
#    'contract_address': '0x111111111117dc0aa78b770fa6a738034120c302'}],
#  '_internal_temp_agora_id': 'f67fad42-4b8a-4c9a-9fd9-27ac3df720a1',
#  'profile': {'general': {'overview': {'is_verified': False,
#     'tagline': 'Decentralized Exchange Aggregator',
#     'category': 'Financial',
#     'sector': 'Decentralized Exchanges',
#     'tags': 'DeFi',
# ...

# %%
response.status_code
# Out:
# 200

# %%
profile = m.read_profile()

# %%
del profile["BTC"]

# %%
def printProgressBar (iteration, total, prefix = '', suffix = '', decimals = 1, length = 100, fill = '█', printEnd = "\r"):
    """
    Call in a loop to create terminal progress bar
    @params:
        iteration   - Required  : current iteration (Int)
        total       - Required  : total iterations (Int)
        prefix      - Optional  : prefix string (Str)
        suffix      - Optional  : suffix string (Str)
        decimals    - Optional  : positive number of decimals in percent complete (Int)
        length      - Optional  : character length of bar (Int)
        fill        - Optional  : bar fill character (Str)
        printEnd    - Optional  : end character (e.g. "\r", "\r\n") (Str)
    """
    percent = ("{0:." + str(decimals) + "f}").format(100 * (iteration / float(total)))
    filledLength = int(length * iteration // total)
    bar = fill * filledLength + '-' * (length - filledLength)
    print(f'\r{prefix} |{bar}| {percent}% {suffix}', end = printEnd)
    # Print New Line on Complete
    if iteration == total: 
        print()

# %%
import time

# %%
for i in range(10):
    time.sleep(1)
    printProgressBar(i, 9, length=50)
# Out:
#  |██████████████████████████████████████████████████| 100.0%

# %%
profile["BTC"] = {"thing":[123]}

# %%
m.save_profile(profile)

# %%
df = m.get_all_margin_assets()

# %%
list(map(lambda x: x['base'], df))
# Out:
# ['1INCH',
#  'AAVE',
#  'ADA',
#  'AERGO',
#  'AGLD',
#  'AION',
#  'AKRO',
#  'ALCX',
#  'ALGO',
#  'ALICE',
#  'ALPACA',
#  'ALPHA',
#  'AMP',
#  'ANKR',
#  'ANT',
#  'ANY',
#  'AR',
#  'ARDR',
#  'ARPA',
#  'ATA',
#  'ATOM',
#  'AUCTION',
#  'AUDIO',
#  'AUTO',
#  'AVA',
#  'AVAX',
#  'AXS',
#  'BADGER',
#  'BAKE',
#  'BAL',
#  'BAND',
#  'BAT',
#  'BCH',
#  'BEL',
#  'BETA',
#  'BICO',
#  'BLZ',
#  'BNB',
#  'BNT',
#  'BNX',
#  'BOND',
#  'BQX',
#  'BTCST',
#  'BTG',
#  'BTS',
#  'BZRX',
#  'C98',
#  'CAKE',
#  'CELO',
#  'CELR',
#  'CFX',
#  'CHESS',
#  'CHR',
#  'CHZ',
#  'CKB',
#  'CLV',
#  'COMP',
#  'COS',
#  'COTI',
#  'CRV',
#  'CTK',
#  'CTSI',
#  'CTXC',
#  'CVC',
#  'CVX',
#  'DAR',
#  'DASH',
#  'DATA',
#  'DCR',
#  'DEGO',
#  'DGB',
#  'DIA',
#  'DNT',
#  'DOCK',
#  'DODO',
#  'DOGE',
#  'DOT',
#  'DREP',
#  'DUSK',
#  'DYDX',
#  'EGLD',
#  'ELF',
#  'ENJ',
#  'ENS',
#  'EOS',
#  'ETC',
#  'ETH',
#  'FARM',
#  'FET',
#  'FIL',
#  'FIO',
#  'FIRO',
#  'FIS',
#  'FLM',
# ...

# %%
df
# Out:
# [{'symbol': '1INCHBTC',
#   'base': '1INCH',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'symbol': 'AAVEBTC',
#   'base': 'AAVE',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'symbol': 'ADABTC',
#   'base': 'ADA',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'symbol': 'AERGOBTC',
#   'base': 'AERGO',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'symbol': 'AGLDBTC',
#   'base': 'AGLD',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'symbol': 'AIONBTC',
#   'base': 'AION',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
#   'isSellAllowed': True},
#  {'symbol': 'AKROBTC',
#   'base': 'AKRO',
#   'quote': 'BTC',
#   'isMarginTrade': True,
#   'isBuyAllowed': True,
# ...

# %%
client.

# %%
df = m.get_timeseries_data("DOGEBTC")

# %%
df
# Out:
#                              open          high           low         close  \
# timestamp
# 2019-07-05 05:00:00  4.200000e-07  4.300000e-07  3.300000e-07  3.500000e-07
# 2019-07-05 06:00:00  3.500000e-07  3.600000e-07  3.300000e-07  3.500000e-07
# 2019-07-05 07:00:00  3.500000e-07  3.500000e-07  3.300000e-07  3.400000e-07
# 2019-07-05 08:00:00  3.400000e-07  3.500000e-07  3.300000e-07  3.300000e-07
# 2019-07-05 09:00:00  3.400000e-07  3.400000e-07  3.200000e-07  3.200000e-07
# ...                           ...           ...           ...           ...
# 2022-01-19 19:00:00  3.900000e-06  3.960000e-06  3.890000e-06  3.930000e-06
# 2022-01-19 20:00:00  3.940000e-06  3.940000e-06  3.910000e-06  3.940000e-06
# 2022-01-19 21:00:00  3.930000e-06  3.940000e-06  3.910000e-06  3.920000e-06
# 2022-01-19 22:00:00  3.920000e-06  3.930000e-06  3.910000e-06  3.920000e-06
# 2022-01-19 23:00:00  3.920000e-06  3.920000e-06  3.920000e-06  3.920000e-06
#
#                            volume
# ...

# %%
client = bh.new_binance_client()

# %%
all_assets = client.get_all_isolated_margin_symbols()

# %%
len(all_assets)
# Out:
# 826

# %%
list(filter(lambda x: x['isMarginTrade']==True, all_assets))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4n/h7p57sb17sn7vtrtjz3m1xhr0000gn/T/ipykernel_11124/3265145315.py in <module>
# ----> 1 list(filter(lambda x: x['isMarginTrade']==True, all_assets))
#
# NameError: name 'all_assets' is not defined

# %%
df = dl.get_timeseries_data("MATICBTC", span="h")

# %%
df
# Out:
#                              open          high           low         close  \
# timestamp
# 2019-04-26 08:00:00  4.900000e-07  1.990000e-06  4.900000e-07  1.190000e-06
# 2019-04-26 09:00:00  1.190000e-06  1.190000e-06  1.070000e-06  1.110000e-06
# 2019-04-26 10:00:00  1.100000e-06  1.110000e-06  9.900000e-07  1.000000e-06
# 2019-04-26 11:00:00  1.010000e-06  1.050000e-06  9.500000e-07  9.600000e-07
# 2019-04-26 12:00:00  9.500000e-07  9.700000e-07  9.100000e-07  9.400000e-07
# ...                           ...           ...           ...           ...
# 2022-01-18 19:00:00  4.941000e-05  4.967000e-05  4.930000e-05  4.955000e-05
# 2022-01-18 20:00:00  4.955000e-05  4.989000e-05  4.952000e-05  4.976000e-05
# 2022-01-18 21:00:00  4.976000e-05  4.989000e-05  4.963000e-05  4.968000e-05
# 2022-01-18 22:00:00  4.969000e-05  4.989000e-05  4.953000e-05  4.958000e-05
# 2022-01-18 23:00:00  4.957000e-05  4.960000e-05  4.905000e-05  4.906000e-05
#
#                            volume
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 4))
d = df[:]
ax.plot(d.tbb, c="gray")
ax1 = ax.twinx()
ax1.plot(d.close)

# %%
df.open.plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>
